# %% [markdown]
# # DBC_10 Quiz: Material Master Data: Data Setup

# %% [markdown]
# ## Importing Libraries

# %%
from pyspark.sql.functions import *
from pyspark.sql.types import *

# %% [markdown]
# ## Environment Setup

# %%
spark.sql("USE CATALOG `workspace`")
spark.sql("USE SCHEMA `mmd_schema`")

# %% [markdown]
# ## Source MMD Data populate to Databricks Source Table from CSV

# %%
# Source Schema Implementation
# Copy data from data store to Source table in Databricks

# Read data from data store ('csv')
df = spark.read.option(
    "inferSchema", "true"
).option(
    "header", "true"
).option(
    "sep", "|"
).csv(
    "/Volumes/workspace/mmd_schema/datastore/material_master_1k.csv"
)

# Write data to Databricks Table
df.write.mode("overwrite").saveAsTable("workspace.mmd_schema.source_mmd_data")

# %%
# %sql
ALTER TABLE workspace.mmd_schema.source_mmd_data
SET TBLPROPERTIES (delta.enableChangeDataFeed = true);

# %%
# %sql
SELECT * FROM workspace.mmd_schema.source_mmd_data;
